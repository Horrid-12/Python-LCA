# %%
# Dictionary of Countries and their Food Cuisines
Food = {
    "Italy": "Pasta, Pizza, Gelato",
    "Japan": "Sushi, Ramen, Tempura",
    "Mexico": "Tacos, Enchiladas, Guacamole",
    "India": "Curry, Biryani, Samosa",
}
x = Food["India"]
print("Food Cuisine of India:", x)
# Get Keys
keys = Food.keys()
Food["France"] = "Baguette, Croissant, Ratatouille"
print("Countries:", list(keys))
# Get Values
values = Food.values()
Food["Italy"] = "Pasta, Pizza, Gelato, Risotto"
print("Food Cuisines:", list(values))
# Get Items
items = Food.items()
Food["France"] = "Baguette, Croissant, Ratatouille, Pain au Chocolat"
print("Country-Cuisine Pairs:", list(items))
# Check if a Key Exists
if "Italy" in Food:
    print("Italy is present in the dictionary.")
else: 
    print("Italy is not present in the dictionary.")
if "Spain" in Food:
    print("Spain is present in the dictionary.")
else: 
    print("Spain is not present in the dictionary.")

# Updating Dictonary
Food.update({"Spain": "Paella, Tapas, Churros"})
print("Updated Dictionary:", Food)

# Removing Items
Food.pop("Mexico")
print("After Removing Mexico:", Food)

Food.popitem()
print("After Removing Last Item:", Food)

# Looping
for country, cuisine in Food.items():
    print(f"{country}: {cuisine}")
for country in Food.keys():
    print(country)
for cuisine in Food.values():
    print(cuisine)
# Copying a Dictionary
Food_copy = Food.copy()
print("Copied Dictionary:", Food_copy)
# Nesting Dictionaries (Example: America)
America = {
    "New York": "Bagel, Pizza",
    "Los Angeles": "In-N-Out Burger, Tacos",
    "Chicago": "Deep Dish Pizza, Hot Dogs"
}
Food["America"] = America
print("Dictionary with Nested Dictionaries:", Food)
#Clearing a Dictionary
Food.clear()
print("After Clearing the Dictionary:", Food)
# Out:
# Food Cuisine of India: Curry, Biryani, Samosa
# Countries: ['Italy', 'Japan', 'Mexico', 'India', 'France']
# Food Cuisines: ['Pasta, Pizza, Gelato, Risotto', 'Sushi, Ramen, Tempura', 'Tacos, Enchiladas, Guacamole', 'Curry, Biryani, Samosa', 'Baguette, Croissant, Ratatouille']
# Country-Cuisine Pairs: [('Italy', 'Pasta, Pizza, Gelato, Risotto'), ('Japan', 'Sushi, Ramen, Tempura'), ('Mexico', 'Tacos, Enchiladas, Guacamole'), ('India', 'Curry, Biryani, Samosa'), ('France', 'Baguette, Croissant, Ratatouille, Pain au Chocolat')]
# Italy is present in the dictionary.
# Spain is not present in the dictionary.
# Updated Dictionary: {'Italy': 'Pasta, Pizza, Gelato, Risotto', 'Japan': 'Sushi, Ramen, Tempura', 'Mexico': 'Tacos, Enchiladas, Guacamole', 'India': 'Curry, Biryani, Samosa', 'France': 'Baguette, Croissant, Ratatouille, Pain au Chocolat', 'Spain': 'Paella, Tapas, Churros'}
# After Removing Mexico: {'Italy': 'Pasta, Pizza, Gelato, Risotto', 'Japan': 'Sushi, Ramen, Tempura', 'India': 'Curry, Biryani, Samosa', 'France': 'Baguette, Croissant, Ratatouille, Pain au Chocolat', 'Spain': 'Paella, Tapas, Churros'}
# After Removing Last Item: {'Italy': 'Pasta, Pizza, Gelato, Risotto', 'Japan': 'Sushi, Ramen, Tempura', 'India': 'Curry, Biryani, Samosa', 'France': 'Baguette, Croissant, Ratatouille, Pain au Chocolat'}
# Italy: Pasta, Pizza, Gelato, Risotto
# Japan: Sushi, Ramen, Tempura
# India: Curry, Biryani, Samosa
# France: Baguette, Croissant, Ratatouille, Pain au Chocolat
# Italy
# Japan
# India
# France
# Pasta, Pizza, Gelato, Risotto
# Sushi, Ramen, Tempura
# Curry, Biryani, Samosa
# Baguette, Croissant, Ratatouille, Pain au Chocolat
# Copied Dictionary: {'Italy': 'Pasta, Pizza, Gelato, Risotto', 'Japan': 'Sushi, Ramen, Tempura', 'India': 'Curry, Biryani, Samosa', 'France': 'Baguette, Croissant, Ratatouille, Pain au Chocolat'}
# Dictionary with Nested Dictionaries: {'Italy': 'Pasta, Pizza, Gelato, Risotto', 'Japan': 'Sushi, Ramen, Tempura', 'India': 'Curry, Biryani, Samosa', 'France': 'Baguette, Croissant, Ratatouille, Pain au Chocolat', 'America': {'New York': 'Bagel, Pizza', 'Los Angeles': 'In-N-Out Burger, Tacos', 'Chicago': 'Deep Dish Pizza, Hot Dogs'}}
# After Clearing the Dictionary: {}
